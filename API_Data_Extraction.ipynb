# %%
import pandas as pd
import requests

# %%
response = requests.get("https://api.themoviedb.org/3/movie/top_rated?api_key=7cfcd6a48fbdc9fdb589c3aece7956da&language=en-US&page=2")
temp_df = pd.DataFrame(response.json())
temp_df
# Out:
#     page                                            results  total_pages  \
# 0      2  {'adult': False, 'backdrop_path': '/gavyCu1UaT...          491
# 1      2  {'adult': False, 'backdrop_path': '/xJHokMbljv...          491
# 2      2  {'adult': False, 'backdrop_path': '/bxSBOAD8Au...          491
# 3      2  {'adult': False, 'backdrop_path': '/hZkgoQYus5...          491
# 4      2  {'adult': False, 'backdrop_path': '/uif5fUshJr...          491
# 5      2  {'adult': False, 'backdrop_path': '/uvitbjFU4J...          491
# 6      2  {'adult': False, 'backdrop_path': '/uPYa165sra...          491
# 7      2  {'adult': False, 'backdrop_path': '/alQqTpmEkx...          491
# 8      2  {'adult': False, 'backdrop_path': '/x2RS3uTcsJ...          491
# 9      2  {'adult': False, 'backdrop_path': '/qUq3QTr2KL...          491
# 10     2  {'adult': False, 'backdrop_path': '/w2uGvCpMtv...          491
# 11     2  {'adult': False, 'backdrop_path': '/uBZQOYZLIU...          491
# ...

# %%
dfs=[]
for i in range(1,478):
    response = requests.get(f'https://api.themoviedb.org/3/movie/top_rated?api_key=7cfcd6a48fbdc9fdb589c3aece7956da&language=en-US&page={i}')
    temp_df = pd.DataFrame(response.json()['results'])[['id','title']]
    dfs.append(temp_df)
    temp_df = pd.concat(dfs,ignore_index=True)
# Out:
# ---------------------------------------------------------------------------
# gaierror                                  Traceback (most recent call last)
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\urllib3\connection.py:196, in HTTPConnection._new_conn(self)
#     195 try:
# --> 196     sock = connection.create_connection(
#     197         (self._dns_host, self.port),
#     198         self.timeout,
#     199         source_address=self.source_address,
#     200         socket_options=self.socket_options,
#     201     )
#     202 except socket.gaierror as e:
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\urllib3\util\connection.py:60, in create_connection(address, timeout, source_address, socket_options)
#      58     raise LocationParseError(f"'{host}', label empty or too long") from None
# ...

# %%
temp_df
# Out:
#           id                              title
# 0        278           The Shawshank Redemption
# 1        238                      The Godfather
# 2        240              The Godfather Part II
# 3        424                   Schindler's List
# 4        389                       12 Angry Men
# ...      ...                                ...
# 9535   11546  Police Academy: Mission to Moscow
# 9536  765119                         The Bubble
# 9537   79316                        Devil's Due
# 9538   11442            Halloween: Resurrection
# 9539  331446           Sharknado 3: Oh Hell No!
#
# [9540 rows x 2 columns]

# %%
temp_df.to_csv('ls.csv')

# %%
temp_df = pd.DataFrame(response.json())
temp_df
# Out:
#     page                                            results  total_pages  \
# 0    477  {'adult': False, 'backdrop_path': '/iRYEGEbpjb...          483
# 1    477  {'adult': False, 'backdrop_path': '/pprNvcLi63...          483
# 2    477  {'adult': False, 'backdrop_path': '/uhHYfrbc4B...          483
# 3    477  {'adult': False, 'backdrop_path': '/rFn78rHTyh...          483
# 4    477  {'adult': False, 'backdrop_path': '/cRu4ISJZWO...          483
# 5    477  {'adult': False, 'backdrop_path': '/7ELIOvgJhh...          483
# 6    477  {'adult': False, 'backdrop_path': '/jcsHUugPrk...          483
# 7    477  {'adult': False, 'backdrop_path': '/msU3F9DVNF...          483
# 8    477  {'adult': False, 'backdrop_path': '/oOVWuXkxQR...          483
# 9    477  {'adult': False, 'backdrop_path': '/bqBtjT11WM...          483
# 10   477  {'adult': False, 'backdrop_path': '/nzIiHAjPGm...          483
# 11   477  {'adult': False, 'backdrop_path': '/cQE2dSKpt3...          483
# ...

# %%
response.json()
# Out:
# {'page': 477,
#  'results': [{'adult': False,
#    'backdrop_path': '/iRYEGEbpjbPQrxAXcIg9wlaO2xm.jpg',
#    'genre_ids': [35, 14, 878],
#    'id': 56715,
#    'original_language': 'en',
#    'original_title': 'Just Visiting',
#    'overview': 'A knight and his valet are plagued by a witch, and to repair the damage they make use of the services of a wizard. However, something goes wrong and they are transported from the 12th century to the year 2000. There the knight meets some of his family and slowly learns what this new century is like. However, he still needs to get back to the 12th century to deal with the witch, so he starts looking for a wizard. Remake of  1993 French film Les Visiteurs (The Visitors).',
#    'popularity': 10.554,
#    'poster_path': '/7KqzbefXjADSUE8j2ZsrudvAArY.jpg',
#    'release_date': '2001-04-06',
#    'title': 'Just Visiting',
#    'video': False,
#    'vote_average': 4.684,
#    'vote_count': 649},
#   {'adult': False,
# ...

# %%
temp_df = pd.DataFrame(response.json()['results'])[['id','title']]
temp_df
# Out:
#         id                                      title
# 0    56715                              Just Visiting
# 1   168098                                       Cell
# 2    13166                        Freddy Got Fingered
# 3   297596                         Dying of the Light
# 4   485415                 Day of the Dead: Bloodline
# 5    14863                      Anaconda 3: Offspring
# 6    17455                         Hellraiser: Deader
# 7    10196                         The Last Airbender
# 8   290825                                Yoga Hosers
# 9   276905                          Norm of the North
# 10   15587                                     Safari
# 11  146203                  The Last Exorcism Part II
# 12  529983                            The Poison Rose
# 13    2728                                     Postal
# 14   16780  The Return of the Texas Chainsaw Massacre
# 15   11546          Police Academy: Mission to Moscow
# ...

# %%
import requests
import pandas as pd
url = "https://linkedin-data-api.p.rapidapi.com/company-jobs"

payload = {
	"companyIds": [5383240, 2382910],
	"page": 5
}
headers = {
	"x-rapidapi-key": "d225069d18mshe4c772d6d94f43cp1f182bjsn727ee74b4a8d",
	"x-rapidapi-host": "linkedin-data-api.p.rapidapi.com",
	"Content-Type": "application/json"
}

response = requests.post(url, json=payload, headers=headers)

print(response.json())
# Out:
# {'success': True, 'message': '', 'data': {'items': [{'id': '3986979383', 'title': 'IT Specialist (Data Center Technician), Data Center Operations (DCO) - DCC Communities', 'url': 'https://www.linkedin.com/jobs/view/3986979383', 'referenceId': 'M85ZNHMuvRY0s0+okH3t1g==', 'posterId': '355872060', 'company': {'name': 'Amazon Web Services (AWS)', 'logo': 'https://media.licdn.com/dms/image/v2/C560BAQER_QnUTXrPJw/company-logo_200_200/company-logo_200_200/0/1670264051233/amazon_web_services_logo?e=1736380800&v=beta&t=bZjOpMUUhtpUY-kd__p8M-y6KfosdHWfG8W7VGdj1Es', 'url': 'https://www.linkedin.com/company/amazon-web-services/life', 'staffCountRange': {}, 'headquarter': {}}, 'location': 'Milan, Lombardy, Italy', 'type': 'Full-time', 'postDate': '5 days ago', 'postAt': '2024-10-02 09:53:32 +0000 UTC', 'postedTimestamp': 1727862812000}, {'id': '4043430375', 'title': 'Network Technician , Infrastructure Delivery', 'url': 'https://www.linkedin.com/jobs/view/4043430375', 'referenceId': 'M85ZNHMuvRY0
# ...

# %%
temp_df = pd.DataFrame(response.json())
temp_df
# Out:
#        success message                                               data
# items     True          [{'id': '3986979383', 'title': 'IT Specialist ...
# total     True                                                      12245

# %%
dfs=[]
for i in range(1,478):
    response = requests.get(f'''
    url = "https://linkedin-data-api.p.rapidapi.com/company-jobs"
    
    payload = {
    	"companyIds": [5383240, 2382910],
    	"page": {i}
    }§
    headers = {
    	"x-rapidapi-key": "d225069d18mshe4c772d6d94f43cp1f182bjsn727ee74b4a8d",
    	"x-rapidapi-host": "linkedin-data-api.p.rapidapi.com",
    	"Content-Type": "application/json"
    }
    
    response = requests.post(url, json=payload, headers=headers)


''')
    temp_df = pd.DataFrame(response.json()['results'])[['id','title']]
    dfs.append(temp_df)
    temp_df = pd.concat(dfs,ignore_index=True)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[11], line 6
#       1 dfs=[]
#       2 for i in range(1,478):
#       3     response = requests.get(f'''
#       4     url = "https://linkedin-data-api.p.rapidapi.com/company-jobs"
#       5
# ----> 6     payload = {
#       7     	"companyIds": [5383240, 2382910],
#       8     	"page": {i}
#       9     }§
#      10     headers = {
#      11     	"x-rapidapi-key": "d225069d18mshe4c772d6d94f43cp1f182bjsn727ee74b4a8d",
#      12     	"x-rapidapi-host": "linkedin-data-api.p.rapidapi.com",
#      13     	"Content-Type": "application/json"
#      14     }
#      15
#      16     response = requests.post(url, json=payload, headers=headers)
#      17
#      18
#      19 ''')
#      20     temp_df = pd.DataFrame(response.json()['results'])[['id','title']]
#      21     dfs.append(temp_df)
#
# ...
